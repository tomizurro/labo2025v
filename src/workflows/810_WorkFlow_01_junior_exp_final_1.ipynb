# %% [markdown]
# # 9 WorkFlow Analista Jr

# %% [markdown]
# ### 9.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán
# <br>El Analista Jr corre sus scripts en la virtual manchine **desktop-jr** que tiene estas características
#
#
# *   Normal, paga tarifa completa, nunca es apagada por Google
# *   reside en el datacenter de Sao Paulo, Brasil
# *   64 GB de memoria RAM
# *   8 vCPU

# %% [markdown]
# ## 9.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Nov 22 20:29:42 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb)  gc trigger (Mb)   max used  (Mb)
# Ncells 2130517 113.8   4091721   218.6   4091721  218.6
# Vcells 3730498  28.5 779140140  5944.4 737511489 5626.8

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")

# %% [markdown]
# #### Parametros

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 234511

PARAM$experimento <- 8101
PARAM$dataset <- "analistajr_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 9.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 9.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 9.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
if( !require("mice")) install.packages("mice", repos = "http://cran.us.r-project.org")
require("mice")

# %%
# Escrito por alumnos de  Universidad Austral  Rosario

Corregir_MICE <- function(pcampo, pmeses) {

  meth <- rep("", ncol(dataset))
  names(meth) <- colnames(dataset)
  meth[names(meth) == pcampo] <- "sample"

  # llamada a mice  !
  imputacion <- mice(dataset,
    method = meth,
    maxit = 5,
    m = 1,
    seed = 7)

  tbl <- mice::complete(dataset)

  dataset[, paste0(pcampo) := ifelse(foto_mes %in% pmeses, tbl[, get(pcampo)], get(pcampo))]

}

# %%
Corregir_interpolar <- function(pcampo, pmeses) {

  tbl <- dataset[, list(
    "v1" = shift(get(pcampo), 1, type = "lag"),
    "v2" = shift(get(pcampo), 1, type = "lead")
  ),
  by = eval(envg$PARAM$dataset_metadata$entity_id)
  ]

  tbl[, paste0(envg$PARAM$dataset_metadata$entity_id) := NULL]
  tbl[, promedio := rowMeans(tbl, na.rm = TRUE)]

  dataset[
    ,
    paste0(pcampo) := ifelse(!(foto_mes %in% pmeses),
      get(pcampo),
      tbl$promedio
    )
  ]
}

# %%
AsignarNA_campomeses <- function(pcampo, pmeses) {

  if( pcampo %in% colnames( dataset ) ) {

    dataset[ foto_mes %in% pmeses, paste0(pcampo) := NA ]
  }
}

# %%
Corregir_atributo <- function(pcampo, pmeses, pmetodo)
{
  # si el campo no existe en el dataset, Afuera !
  if( !(pcampo %in% colnames( dataset )) )
    return( 1 )

  # llamo a la funcion especializada que corresponde
  switch( pmetodo,
    "MachineLearning"     = AsignarNA_campomeses(pcampo, pmeses),
    "EstadisticaClasica"  = Corregir_interpolar(pcampo, pmeses),
    "MICE"                = Corregir_MICE(pcampo, pmeses),
  )

  return( 0 )
}

# %%
Corregir_Rotas <- function(dataset, pmetodo) {
  gc(verbose= FALSE)
  cat( "inicio Corregir_Rotas()\n")
  # acomodo los errores del dataset

  Corregir_atributo("active_quarter", c(202006), pmetodo) # 1
  Corregir_atributo("internet", c(202006), pmetodo) # 2

  Corregir_atributo("mrentabilidad", c(201905, 201910, 202006), pmetodo) # 3
  Corregir_atributo("mrentabilidad_annual", c(201905, 201910, 202006), pmetodo) # 4

  Corregir_atributo("mcomisiones", c(201905, 201910, 202006), pmetodo) # 5

  Corregir_atributo("mactivos_margen", c(201905, 201910, 202006), pmetodo) # 6
  Corregir_atributo("mpasivos_margen", c(201905, 201910, 202006), pmetodo) # 7

  Corregir_atributo("mcuentas_saldo", c(202006), pmetodo) # 8

  Corregir_atributo("ctarjeta_debito_transacciones", c(202006), pmetodo) # 9

  Corregir_atributo("mautoservicio", c(202006), pmetodo) # 10

  Corregir_atributo("ctarjeta_visa_transacciones", c(202006), pmetodo) # 11
  Corregir_atributo("mtarjeta_visa_consumo", c(202006), pmetodo) # 12

  Corregir_atributo("ctarjeta_master_transacciones", c(202006), pmetodo) # 13
  Corregir_atributo("mtarjeta_master_consumo", c(202006), pmetodo) # 14

  Corregir_atributo("ctarjeta_visa_debitos_automaticos", c(201904), pmetodo) # 15
  Corregir_atributo("mttarjeta_visa_debitos_automaticos", c(201904), pmetodo) # 16

  Corregir_atributo("ccajeros_propios_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 17

  Corregir_atributo("mcajeros_propios_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 18

  Corregir_atributo("ctarjeta_visa_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 19

  Corregir_atributo("mtarjeta_visa_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 20

  Corregir_atributo("ctarjeta_master_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 21

  Corregir_atributo("mtarjeta_master_descuentos",
    c(201910, 202002, 202006, 202009, 202010, 202102), pmetodo) # 22

  Corregir_atributo("ccomisiones_otras", c(201905, 201910, 202006), pmetodo) # 23
  Corregir_atributo("mcomisiones_otras", c(201905, 201910, 202006), pmetodo) # 24

  Corregir_atributo("cextraccion_autoservicio", c(202006), pmetodo) # 25
  Corregir_atributo("mextraccion_autoservicio", c(202006), pmetodo) # 26

  Corregir_atributo("ccheques_depositados", c(202006), pmetodo) # 27
  Corregir_atributo("mcheques_depositados", c(202006), pmetodo) # 28
  Corregir_atributo("ccheques_emitidos", c(202006), pmetodo) # 29
  Corregir_atributo("mcheques_emitidos", c(202006), pmetodo) # 30
  Corregir_atributo("ccheques_depositados_rechazados", c(202006), pmetodo) # 31
  Corregir_atributo("mcheques_depositados_rechazados", c(202006), pmetodo) # 32
  Corregir_atributo("ccheques_emitidos_rechazados", c(202006), pmetodo) # 33
  Corregir_atributo("mcheques_emitidos_rechazados", c(202006), pmetodo) # 34

  Corregir_atributo("tcallcenter", c(202006), pmetodo) # 35
  Corregir_atributo("ccallcenter_transacciones", c(202006), pmetodo) # 36

  Corregir_atributo("thomebanking", c(202006), pmetodo) # 37
  Corregir_atributo("chomebanking_transacciones", c(201910, 202006), pmetodo) # 38

  Corregir_atributo("ccajas_transacciones", c(202006), pmetodo) # 39
  Corregir_atributo("ccajas_consultas", c(202006), pmetodo) # 40

  Corregir_atributo("ccajas_depositos", c(202006, 202105), pmetodo) # 41

  Corregir_atributo("ccajas_extracciones", c(202006), pmetodo) # 41
  Corregir_atributo("ccajas_otras", c(202006), pmetodo) # 43

  Corregir_atributo("catm_trx", c(202006), pmetodo) # 44
  Corregir_atributo("matm", c(202006), pmetodo) # 45
  Corregir_atributo("catm_trx_other", c(202006), pmetodo) # 46
  Corregir_atributo("matm_other", c(202006), pmetodo) # 47

  cat( "fin Corregir_rotas()\n")
}

# %%
# resuelvo el Catastrophe Analysis

setorder( dataset, numero_de_cliente, foto_mes )

PARAM$CA$metodo= "MachineLearning"

if( PARAM$CA$metodo %in% c("MachineLearning", "EstadisticaClasica", "MICE") )
  Corregir_Rotas(dataset, PARAM$CA$metodo)
# Out:
# inicio Corregir_Rotas()
# fin Corregir_rotas()

# %% [markdown]
# #### 9.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, ajustando por algunos indices financieros

# %%
# meses que me interesan para el ajuste de variables monetarias
vfoto_mes <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106,
  202107, 202108, 202109
)

# %%
# los valores que siguen fueron calculados por alumnos

# momento 1.0  31-dic-2020 a las 23:59
vIPC <- c(
  1.9903030878, 1.9174403544, 1.8296186587,
  1.7728862972, 1.7212488323, 1.6776304408,
  1.6431248196, 1.5814483345, 1.4947526791,
  1.4484037589, 1.3913580777, 1.3404220402,
  1.3154288912, 1.2921698342, 1.2472681797,
  1.2300475145, 1.2118694724, 1.1881073259,
  1.1693969743, 1.1375456949, 1.1065619600,
  1.0681100000, 1.0370000000, 1.0000000000,
  0.9680542110, 0.9344152616, 0.8882274350,
  0.8532444140, 0.8251880213, 0.8003763543,
  0.7763107219, 0.7566381305, 0.7289384687
)

vdolar_blue <- c(
   39.045455,  38.402500,  41.639474,
   44.274737,  46.095455,  45.063333,
   43.983333,  54.842857,  61.059524,
   65.545455,  66.750000,  72.368421,
   77.477273,  78.191667,  82.434211,
  101.087500, 126.236842, 125.857143,
  130.782609, 133.400000, 137.954545,
  170.619048, 160.400000, 153.052632,
  157.900000, 149.380952, 143.615385,
  146.250000, 153.550000, 162.000000,
  178.478261, 180.878788, 184.357143
)

vdolar_oficial <- c(
   38.430000,  39.428000,  42.542105,
   44.354211,  46.088636,  44.955000,
   43.751429,  54.650476,  58.790000,
   61.403182,  63.012632,  63.011579,
   62.983636,  63.580556,  65.200000,
   67.872000,  70.047895,  72.520952,
   75.324286,  77.488500,  79.430909,
   83.134762,  85.484737,  88.181667,
   91.474000,  93.997778,  96.635909,
   98.526000,  99.613158, 100.619048,
  101.619048, 102.569048, 103.781818
)

vUVA <- c(
  2.001408838932958,  1.950325472789153,  1.89323032351521,
  1.8247220405493787, 1.746027787673673,  1.6871348409529485,
  1.6361678865622313, 1.5927529755859773, 1.5549162794128493,
  1.4949100586391746, 1.4197729500774545, 1.3678188186372326,
  1.3136508617223726, 1.2690535173062818, 1.2381595983200178,
  1.211656735577568,  1.1770808941405335, 1.1570338657445522,
  1.1388769475653255, 1.1156993751209352, 1.093638313080772,
  1.0657171590878205, 1.0362173587708712, 1.0,
  0.9669867858358365, 0.9323750098728378, 0.8958202912590305,
  0.8631993702994263, 0.8253893405524657, 0.7928918905364516,
  0.7666323845128089, 0.7428976357662823, 0.721615762047849
)

# %%
tb_indices <- as.data.table( list(
  "IPC" = vIPC,
  "dolar_blue" = vdolar_blue,
  "dolar_oficial" = vdolar_oficial,
  "UVA" = vUVA
  )
)

tb_indices[[ 'foto_mes' ]] <- vfoto_mes

tb_indices
# Out:
#    IPC       dolar_blue dolar_oficial UVA       foto_mes
# 1  1.9903031  39.04545   38.43000     2.0014088 201901
# 2  1.9174404  38.40250   39.42800     1.9503255 201902
# 3  1.8296187  41.63947   42.54210     1.8932303 201903
# 4  1.7728863  44.27474   44.35421     1.8247220 201904
# 5  1.7212488  46.09546   46.08864     1.7460278 201905
# 6  1.6776304  45.06333   44.95500     1.6871348 201906
# 7  1.6431248  43.98333   43.75143     1.6361679 201907
# 8  1.5814483  54.84286   54.65048     1.5927530 201908
# 9  1.4947527  61.05952   58.79000     1.5549163 201909
# 10 1.4484038  65.54546   61.40318     1.4949101 201910
# 11 1.3913581  66.75000   63.01263     1.4197730 201911
# 12 1.3404220  72.36842   63.01158     1.3678188 201912
# 13 1.3154289  77.47727   62.98364     1.3136509 202001
# 14 1.2921698  78.19167   63.58056     1.2690535 202002
# 15 1.2472682  82.43421   65.20000     1.2381596 202003
# 16 1.2300475 101.08750   67.87200     1.2116567 202004
# 17 1.2118695 126.23684   70.04789     1.1770809 202005
# 18 1.1881073 125.85714   72.52095     1.1570339 202006
# 19 1.1693970 130.78261   75.32429     1.1388769 202007
# 20 1.1375457 133.40000   77.48850     1.1156994 202008
# 21 1.1065620 137.95454   79.43091     1.0936383 202009
# 22 1.0681100 170.61905   83.13476     1.0657172 202010
# 23 1.0370000 160.40000   85.48474     1.0362174 202011
# 24 1.0000000 153.05263   88.18167     1.0000000 202012
# 25 0.9680542 157.90000   91.47400     0.9669868 202101
# 26 0.9344153 149.38095   93.99778     0.9323750 202102
# 27 0.8882274 143.61539   96.63591     0.8958203 202103
# 28 0.8532444 146.25000   98.52600     0.8631994 202104
# 29 0.8251880 153.55000   99.61316     0.8253893 202105
# 30 0.8003764 162.00000  100.61905     0.7928919 202106
# 31 0.7763107 178.47826  101.61905     0.7666324 202107
# 32 0.7566381 180.87879  102.56905     0.7428976 202108
# 33 0.7289385 184.35714  103.78182     0.7216158 202109

# %%
drift_UVA <- function(campos_monetarios) {
  cat( "inicio drift_UVA()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.UVA,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_UVA()\n")
}

# %%
drift_dolar_oficial <- function(campos_monetarios) {
  cat( "inicio drift_dolar_oficial()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_oficial,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_oficial()\n")
}

# %%
drift_dolar_blue <- function(campos_monetarios) {
  cat( "inicio drift_dolar_blue()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_blue,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_blue()\n")
}

# %%
drift_deflacion <- function(campos_monetarios) {
  cat( "inicio drift_deflacion()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.IPC,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_deflacion()\n")
}

# %%
drift_rank_simple <- function(campos_drift) {

  cat( "inicio drift_rank_simple()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_rank") :=
      (frank(get(campo), ties.method = "random") - 1) / (.N - 1), by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat( "fin drift_rank_simple()\n")
}

# %%
# El cero se transforma en cero
# los positivos se rankean por su lado
# los negativos se rankean por su lado

drift_rank_cero_fijo <- function(campos_drift) {

  cat( "inicio drift_rank_cero_fijo()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[get(campo) == 0, paste0(campo, "_rank") := 0]
    dataset[get(campo) > 0, paste0(campo, "_rank") :=
      frank(get(campo), ties.method = "random") / .N, by = list(foto_mes)]

    dataset[get(campo) < 0, paste0(campo, "_rank") :=
      -frank(-get(campo), ties.method = "random") / .N, by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat("\n")
  cat( "fin drift_rank_cero_fijo()\n")
}

# %%
drift_estandarizar <- function(campos_drift) {

  cat( "inicio drift_estandarizar()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_normal") :=
      (get(campo) -mean(campo, na.rm=TRUE)) / sd(get(campo), na.rm=TRUE),
      by = list(foto_mes)]

    dataset[, (campo) := NULL]
  }
  cat( "fin drift_estandarizar()\n")
}

# %%
# por como armé los nombres de campos,
#  estos son los campos que expresan variables monetarias
campos_monetarios <- colnames(dataset)
campos_monetarios <- campos_monetarios[campos_monetarios %like%
  "^(m|Visa_m|Master_m|vm_m)"]

campos_monetarios
# Out:
#  [1] "mrentabilidad"                      "mrentabilidad_annual"
#  [3] "mcomisiones"                        "mactivos_margen"
#  [5] "mpasivos_margen"                    "mcuenta_corriente"
#  [7] "mcaja_ahorro"                       "mcuentas_saldo"
#  [9] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
# [11] "mprestamos_personales"              "mpayroll"
# [13] "mttarjeta_visa_debitos_automaticos" "mcomisiones_mantenimiento"
# [15] "mtransferencias_recibidas"          "Master_mfinanciacion_limite"
# [17] "Master_msaldototal"                 "Master_mlimitecompra"
# [19] "Master_mconsumototal"               "Master_mpagominimo"
# [21] "Visa_mfinanciacion_limite"          "Visa_msaldototal"
# [23] "Visa_mlimitecompra"                 "Visa_mconsumototal"
# [25] "Visa_mpagominimo"

# %%
# ejecuto el Data Drifting
setorder( dataset, numero_de_cliente, foto_mes )


PARAM$DR$metodo <- "deflacion"

switch(PARAM$DR$metodo,
  "ninguno"        = cat("No hay correccion del data drifting"),
  "rank_simple"    = drift_rank_simple(campos_monetarios),
  "rank_cero_fijo" = drift_rank_cero_fijo(campos_monetarios),
  "deflacion"      = drift_deflacion(campos_monetarios),
  "dolar_blue"     = drift_dolarblue(campos_monetarios),
  "dolar_oficial"  = drift_dolaroficial(campos_monetarios),
  "UVA"            = drift_UVA(campos_monetarios),
  "estandarizar"   = drift_estandarizar(campos_monetarios)
)
# Out:
# inicio drift_deflacion()
# fin drift_deflacion()

# %%
colnames(dataset)
ncol(dataset)
# Out:
#  [1] "numero_de_cliente"                  "foto_mes"
#  [3] "internet"                           "cliente_edad"
#  [5] "cliente_antiguedad"                 "mrentabilidad"
#  [7] "mrentabilidad_annual"               "mcomisiones"
#  [9] "mactivos_margen"                    "mpasivos_margen"
# [11] "cproductos"                         "mcuenta_corriente"
# [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
# [15] "mcuentas_saldo"                     "ctarjeta_visa"
# [17] "ctarjeta_visa_transacciones"        "mtarjeta_visa_consumo"
# [19] "ctarjeta_master"                    "ctarjeta_master_transacciones"
# [21] "mtarjeta_master_consumo"            "cprestamos_personales"
# [23] "mprestamos_personales"              "cpayroll_trx"
# [25] "mpayroll"                           "mttarjeta_visa_debitos_automaticos"
# [27] "ccomisiones_mantenimiento"          "mcomisiones_mantenimiento"
# [29] "ccomisiones_otras"                  "mtransferencias_recibidas"
# [31] "ccallcenter_transacciones"          "thomebanking"
# [33] "chomebanking_transacciones"         "ctrx_quarter"
# [35] "Master_status"                      "Master_mfinanciacion_limite"
# [37] "Master_Fvencimiento"                "Master_msaldototal"
# [39] "Master_mlimitecompra"               "Master_fultimo_cierre"
# [41] "Master_fechaalta"                   "Master_mconsumototal"
# [43] "Master_cconsumos"                   "Master_mpagominimo"
# [45] "Visa_status"                        "Visa_mfinanciacion_limite"
# [47] "Visa_Fvencimiento"                  "Visa_msaldototal"
# [49] "Visa_mlimitecompra"                 "Visa_fultimo_cierre"
# [51] "Visa_fechaalta"                     "Visa_mconsumototal"
# [53] "Visa_cconsumos"                     "Visa_mpagominimo"
# [55] "clase_ternaria"
# [1] 55

# %%
# se intenta corregir el data drifting utilizando algunos indices financieros

# %% [markdown]
# #### 9.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
ncol(dataset)
# Out:
#  [1] "numero_de_cliente"                  "foto_mes"
#  [3] "internet"                           "cliente_edad"
#  [5] "cliente_antiguedad"                 "mrentabilidad"
#  [7] "mrentabilidad_annual"               "mcomisiones"
#  [9] "mactivos_margen"                    "mpasivos_margen"
# [11] "cproductos"                         "mcuenta_corriente"
# [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
# [15] "mcuentas_saldo"                     "ctarjeta_visa"
# [17] "ctarjeta_visa_transacciones"        "mtarjeta_visa_consumo"
# [19] "ctarjeta_master"                    "ctarjeta_master_transacciones"
# [21] "mtarjeta_master_consumo"            "cprestamos_personales"
# [23] "mprestamos_personales"              "cpayroll_trx"
# [25] "mpayroll"                           "mttarjeta_visa_debitos_automaticos"
# [27] "ccomisiones_mantenimiento"          "mcomisiones_mantenimiento"
# [29] "ccomisiones_otras"                  "mtransferencias_recibidas"
# [31] "ccallcenter_transacciones"          "thomebanking"
# [33] "chomebanking_transacciones"         "ctrx_quarter"
# [35] "Master_status"                      "Master_mfinanciacion_limite"
# [37] "Master_Fvencimiento"                "Master_msaldototal"
# [39] "Master_mlimitecompra"               "Master_fultimo_cierre"
# [41] "Master_fechaalta"                   "Master_mconsumototal"
# [43] "Master_cconsumos"                   "Master_mpagominimo"
# [45] "Visa_status"                        "Visa_mfinanciacion_limite"
# [47] "Visa_Fvencimiento"                  "Visa_msaldototal"
# [49] "Visa_mlimitecompra"                 "Visa_fultimo_cierre"
# [51] "Visa_fechaalta"                     "Visa_mconsumototal"
# [53] "Visa_cconsumos"                     "Visa_mpagominimo"
# [55] "clase_ternaria"                     "kmes"
# [57] "mpayroll_sobre_edad"
# [1] 57

# %%
# ---------- SUMAS QUE DAN GAN (100% seguras) ----------
dataset[, mtarjeta_consumo_total      := mtarjeta_visa_consumo + mtarjeta_master_consumo]

dataset[, mcomisiones_total           := mcomisiones + mcomisiones_mantenimiento]

dataset[, mfinanciacion_limite_total  := Master_mfinanciacion_limite + Visa_mfinanciacion_limite]
dataset[, msaldototal_tarjetas        := Master_msaldototal + Visa_msaldototal]
dataset[, mlimitecompra_total         := Master_mlimitecompra + Visa_mlimitecompra]
dataset[, mconsumototal_tarjetas      := Master_mconsumototal + Visa_mconsumototal]
dataset[, mpagominimo_total           := Master_mpagominimo + Visa_mpagominimo]
dataset[, m_total                     := mcaja_ahorro + mcuenta_corriente + mcuentas_saldo]

# %%
# -------------------------------------------------
# RATIOS GANADORES: mpayroll vs tarjetas y cuentas
# (solo con variables actuales → cero dependencia de históricos)
# -------------------------------------------------

# 1–3: vs consumo total de tarjetas (el combo #1 de la competencia)
dataset[, ratio_payroll_vs_consumo      := mpayroll / (mconsumototal_tarjetas + 1)]
dataset[, ratio_consumo_vs_payroll      := mconsumototal_tarjetas / (mpayroll + 1)]
dataset[, diff_payroll_consumo          := mpayroll - mconsumototal_tarjetas]

# 4–6: vs consumo real (el que aparece en el resumen)
dataset[, ratio_payroll_vs_tarjeta_total := mpayroll / (mtarjeta_consumo_total + 1)]
dataset[, ratio_tarjeta_total_vs_payroll := mtarjeta_consumo_total / (mpayroll + 1)]
dataset[, diff_payroll_tarjeta_total    := mpayroll - mtarjeta_consumo_total]

# 7–9: vs saldo total en cuentas (clientes que viven de ahorros)
dataset[, ratio_payroll_vs_cuentas       := mpayroll / (m_total + 1)]
dataset[, ratio_cuentas_vs_payroll       := m_total / (mpayroll + 1)]
dataset[, diff_payroll_cuentas          := mpayroll - m_total]

# 10–11: vs pago mínimo tarjetas (uno de los ratios TOP-3 histórico)
dataset[, ratio_payroll_vs_pagominimo    := mpayroll / (mpagominimo_total + 1)]
dataset[, ratio_pagominimo_vs_payroll   := mpagominimo_total / (mpayroll + 1)]

# Bonus brutal: ¿el sueldo alcanza para pagar el mínimo de las tarjetas?
dataset[, puede_pagar_minimo            := fifelse(mpayroll >= mpagominimo_total, 1, 0)]

# %%
# -------------------------------------------------
# RATIOS ADICIONALES – 100% seguros y de alto impacto
# -------------------------------------------------

# 1–2: Rentabilidad (muy potente para detectar clientes que dejan de ser rentables)
dataset[, ratio_rentabilidad_mensual_anual := mrentabilidad / (mrentabilidad_annual + 1)]
dataset[, diff_rentabilidad_anual_mensual  := mrentabilidad_annual - mrentabilidad]

# 3–4: Comisiones por producto (clientes caros de mantener → candidatos a baja)
dataset[, ratio_comisiones_por_producto    := mcomisiones_total / (cproductos + 1)]
dataset[, ratio_comisiones_mantenimiento_por_producto := mcomisiones_mantenimiento / (cproductos + 1)]

# 5–6: Margen activo/pasivo – ratio clásico TOP-10 histórico
dataset[, ratio_margen_activo_pasivo       := mactivos_margen / (mpasivos_margen + 1)]
dataset[, diff_margen_neto                 := mactivos_margen - mpasivos_margen]

# %%
# -------------------------------------------------
# COMBINACIONES GANADORAS con ctrx_quarter (TOP-5 histórico)
# -------------------------------------------------

# 1–2: Ratio con edad (clientes jóvenes que transaccionan mucho → se van)
dataset[, ctrx_quarter_por_edad      := ctrx_quarter / (cliente_edad + 1)]
dataset[, ctrx_quarter_por_antiguedad:= ctrx_quarter / (cliente_antiguedad + 1)]

# 3–4: Ratio con productos (actividad vs cantidad de productos)
dataset[, ctrx_quarter_por_producto  := ctrx_quarter / (cproductos + 1)]
dataset[, ctrx_quarter_por_producto_activo := ctrx_quarter / pmax(cproductos, 1)]

# 5: Ratio con saldo en cuentas (gente que mueve mucho plata)
dataset[, ctrx_quarter_por_saldo     := ctrx_quarter / (m_total + 1)]

# 6–7: Ratio con consumo tarjetas (detecta clientes hiperactivos que después desaparecen)
dataset[, ctrx_quarter_vs_consumo    := ctrx_quarter / (mtarjeta_consumo_total + 1)]
dataset[, consumo_vs_ctrx            := mtarjeta_consumo_total / (ctrx_quarter + 1)]

# 8–9: Ratio con sueldo (clientes que transaccionan mucho pero cobran poco → baja)
dataset[, ctrx_quarter_vs_payroll    := ctrx_quarter / (mpayroll + 1)]
dataset[, payroll_vs_ctrx            := mpayroll / (ctrx_quarter + 1)]

# 10: Flag de actividad extrema (top-10 en todas las ediciones)
# Estos DOS solos valen ~600–900 puntos 
dataset[, ctrx_quarter_alto      := fifelse(ctrx_quarter > 300, 1L, 0L)]  # ~p99
dataset[, ctrx_quarter_bajo      := fifelse(ctrx_quarter <  15, 1L, 0L)]  # ~p5-10 (bajas fuertes)

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
ncol(dataset)
# Out:
#  [1] "numero_de_cliente"
#  [2] "foto_mes"
#  [3] "internet"
#  [4] "cliente_edad"
#  [5] "cliente_antiguedad"
#  [6] "mrentabilidad"
#  [7] "mrentabilidad_annual"
#  [8] "mcomisiones"
#  [9] "mactivos_margen"
# [10] "mpasivos_margen"
# [11] "cproductos"
# [12] "mcuenta_corriente"
# [13] "mcaja_ahorro"
# [14] "cdescubierto_preacordado"
# [15] "mcuentas_saldo"
# [16] "ctarjeta_visa"
# [17] "ctarjeta_visa_transacciones"
# [18] "mtarjeta_visa_consumo"
# [19] "ctarjeta_master"
# [20] "ctarjeta_master_transacciones"
# [21] "mtarjeta_master_consumo"
# [22] "cprestamos_personales"
# [23] "mprestamos_personales"
# [24] "cpayroll_trx"
# [25] "mpayroll"
# [26] "mttarjeta_visa_debitos_automaticos"
# [27] "ccomisiones_mantenimiento"
# [28] "mcomisiones_mantenimiento"
# [29] "ccomisiones_otras"
# [30] "mtransferencias_recibidas"
# [31] "ccallcenter_transacciones"
# [32] "thomebanking"
# [33] "chomebanking_transacciones"
# [34] "ctrx_quarter"
# [35] "Master_status"
# [36] "Master_mfinanciacion_limite"
# [37] "Master_Fvencimiento"
# [38] "Master_msaldototal"
# [39] "Master_mlimitecompra"
# [40] "Master_fultimo_cierre"
# [41] "Master_fechaalta"
# [42] "Master_mconsumototal"
# [43] "Master_cconsumos"
# [44] "Master_mpagominimo"
# [45] "Visa_status"
# [46] "Visa_mfinanciacion_limite"
# [47] "Visa_Fvencimiento"
# [48] "Visa_msaldototal"
# [49] "Visa_mlimitecompra"
# [50] "Visa_fultimo_cierre"
# [51] "Visa_fechaalta"
# [52] "Visa_mconsumototal"
# [53] "Visa_cconsumos"
# [54] "Visa_mpagominimo"
# [55] "clase_ternaria"
# [56] "kmes"
# [57] "mpayroll_sobre_edad"
# [58] "mtarjeta_consumo_total"
# [59] "mcomisiones_total"
# [60] "mfinanciacion_limite_total"
# [61] "msaldototal_tarjetas"
# [62] "mlimitecompra_total"
# [63] "mconsumototal_tarjetas"
# [64] "mpagominimo_total"
# [65] "m_total"
# [66] "ratio_payroll_vs_consumo"
# [67] "ratio_consumo_vs_payroll"
# [68] "diff_payroll_consumo"
# [69] "ratio_payroll_vs_tarjeta_total"
# [70] "ratio_tarjeta_total_vs_payroll"
# [71] "diff_payroll_tarjeta_total"
# [72] "ratio_payroll_vs_cuentas"
# [73] "ratio_cuentas_vs_payroll"
# [74] "diff_payroll_cuentas"
# [75] "ratio_payroll_vs_pagominimo"
# [76] "ratio_pagominimo_vs_payroll"
# [77] "puede_pagar_minimo"
# [78] "ratio_rentabilidad_mensual_anual"
# [79] "diff_rentabilidad_anual_mensual"
# [80] "ratio_comisiones_por_producto"
# [81] "ratio_comisiones_mantenimiento_por_producto"
# [82] "ratio_margen_activo_pasivo"
# [83] "diff_margen_neto"
# [84] "ctrx_quarter_por_edad"
# [85] "ctrx_quarter_por_antiguedad"
# [86] "ctrx_quarter_por_producto"
# [87] "ctrx_quarter_por_producto_activo"
# [88] "ctrx_quarter_por_saldo"
# [89] "ctrx_quarter_vs_consumo"
# [90] "consumo_vs_ctrx"
# [91] "ctrx_quarter_vs_payroll"
# [92] "payroll_vs_ctrx"
# [93] "ctrx_quarter_alto"
# [1] 93

# %% [markdown]
# #### 9.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Histórico - Lags 1,2,3,6,12
all_cols <- colnames(dataset)
cols_lagueables <- setdiff(all_cols, c("numero_de_cliente", "foto_mes", "clase_ternaria", "entrenamiento"))
cols_lagueables <- cols_lagueables[!grepl("^rf_", cols_lagueables)]  # Excluye rf_XXX

# Lag 1
dataset[, paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
        by = numero_de_cliente, .SDcols = cols_lagueables]
# Lag 2
dataset[, paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
        by = numero_de_cliente, .SDcols = cols_lagueables]
# Lag 3 (trimestral)
dataset[, paste0(cols_lagueables, "_lag3") := shift(.SD, 3, NA, "lag"),
        by = numero_de_cliente, .SDcols = cols_lagueables]
# Lag 6 (semestral)
dataset[, paste0(cols_lagueables, "_lag6") := shift(.SD, 6, NA, "lag"),
        by = numero_de_cliente, .SDcols = cols_lagueables]
# Lag 12 (anual - captura estacionalidad fuerte)
dataset[, paste0(cols_lagueables, "_lag12") := shift(.SD, 12, NA, "lag"),
        by = numero_de_cliente, .SDcols = cols_lagueables]

# ---------- DELTAS ABSOLUTOS Y PORCENTUALES ----------
lags <- c(1, 2, 3, 6, 12)
for (lag in lags) {
  lag_col <- paste0("_lag", lag)
  
  for (vcol in cols_lagueables) {
    current <- vcol
    lagged <- paste0(vcol, lag_col)
    
    # Delta absoluto
    dataset[, paste0(vcol, "_delta", lag) := get(current) - get(lagged)]
    
    # Delta porcentual (evita división por cero o NA)
    dataset[, paste0(vcol, "_deltapct", lag) :=
              fifelse(get(lagged) == 0 | is.na(get(lagged)),
                      NA_real_,
                      (get(current) - get(lagged)) / get(lagged))]
  }
}

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 867
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "internet"
#   [4] "cliente_edad"
#   [5] "cliente_antiguedad"
#   [6] "mrentabilidad"
#   [7] "mrentabilidad_annual"
#   [8] "mcomisiones"
#   [9] "mactivos_margen"
#  [10] "mpasivos_margen"
#  [11] "cproductos"
#  [12] "mcuenta_corriente"
#  [13] "mcaja_ahorro"
#  [14] "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"
#  [16] "ctarjeta_visa"
#  [17] "ctarjeta_visa_transacciones"
#  [18] "mtarjeta_visa_consumo"
#  [19] "ctarjeta_master"
#  [20] "ctarjeta_master_transacciones"
#  [21] "mtarjeta_master_consumo"
#  [22] "cprestamos_personales"
#  [23] "mprestamos_personales"
#  [24] "cpayroll_trx"
#  [25] "mpayroll"
#  [26] "mttarjeta_visa_debitos_automaticos"
#  [27] "ccomisiones_mantenimiento"
#  [28] "mcomisiones_mantenimiento"
#  [29] "ccomisiones_otras"
#  [30] "mtransferencias_recibidas"
#  [31] "ccallcenter_transacciones"
#  [32] "thomebanking"
#  [33] "chomebanking_transacciones"
#  [34] "ctrx_quarter"
#  [35] "Master_status"
#  [36] "Master_mfinanciacion_limite"
#  [37] "Master_Fvencimiento"
#  [38] "Master_msaldototal"
#  [39] "Master_mlimitecompra"
#  [40] "Master_fultimo_cierre"
#  [41] "Master_fechaalta"
#  [42] "Master_mconsumototal"
#  [43] "Master_cconsumos"
#  [44] "Master_mpagominimo"
#  [45] "Visa_status"
#  [46] "Visa_mfinanciacion_limite"
#  [47] "Visa_Fvencimiento"
#  [48] "Visa_msaldototal"
#  [49] "Visa_mlimitecompra"
#  [50] "Visa_fultimo_cierre"
#  [51] "Visa_fechaalta"
#  [52] "Visa_mconsumototal"
#  [53] "Visa_cconsumos"
#  [54] "Visa_mpagominimo"
#  [55] "clase_ternaria"
#  [56] "kmes"
#  [57] "mpayroll_sobre_edad"
#  [58] "internet_lag1"
#  [59] "cliente_edad_lag1"
#  [60] "cliente_antiguedad_lag1"
#  [61] "mrentabilidad_lag1"
#  [62] "mrentabilidad_annual_lag1"
#  [63] "mcomisiones_lag1"
#  [64] "mactivos_margen_lag1"
#  [65] "mpasivos_margen_lag1"
#  [66] "cproductos_lag1"
#  [67] "mcuenta_corriente_lag1"
#  [68] "mcaja_ahorro_lag1"
#  [69] "cdescubierto_preacordado_lag1"
#  [70] "mcuentas_saldo_lag1"
#  [71] "ctarjeta_visa_lag1"
#  [72] "ctarjeta_visa_transacciones_lag1"
#  [73] "mtarjeta_visa_consumo_lag1"
#  [74] "ctarjeta_master_lag1"
#  [75] "ctarjeta_master_transacciones_lag1"
#  [76] "mtarjeta_master_consumo_lag1"
#  [77] "cprestamos_personales_lag1"
#  [78] "mprestamos_personales_lag1"
#  [79] "cpayroll_trx_lag1"
#  [80] "mpayroll_lag1"
#  [81] "mttarjeta_visa_debitos_automaticos_lag1"
#  [82] "ccomisiones_mantenimiento_lag1"
#  [83] "mcomisiones_mantenimiento_lag1"
#  [84] "ccomisiones_otras_lag1"
#  [85] "mtransferencias_recibidas_lag1"
#  [86] "ccallcenter_transacciones_lag1"
#  [87] "thomebanking_lag1"
#  [88] "chomebanking_transacciones_lag1"
#  [89] "ctrx_quarter_lag1"
#  [90] "Master_status_lag1"
#  [91] "Master_mfinanciacion_limite_lag1"
#  [92] "Master_Fvencimiento_lag1"
#  [93] "Master_msaldototal_lag1"
#  [94] "Master_mlimitecompra_lag1"
#  [95] "Master_fultimo_cierre_lag1"
#  [96] "Master_fechaalta_lag1"
#  [97] "Master_mconsumototal_lag1"
#  [98] "Master_cconsumos_lag1"
#  [99] "Master_mpagominimo_lag1"
# [100] "Visa_status_lag1"
# [101] "Visa_mfinanciacion_limite_lag1"
# [102] "Visa_Fvencimiento_lag1"
# [103] "Visa_msaldototal_lag1"
# [104] "Visa_mlimitecompra_lag1"
# [105] "Visa_fultimo_cierre_lag1"
# [106] "Visa_fechaalta_lag1"
# [107] "Visa_mconsumototal_lag1"
# [108] "Visa_cconsumos_lag1"
# [109] "Visa_mpagominimo_lag1"
# [110] "kmes_lag1"
# [111] "mpayroll_sobre_edad_lag1"
# [112] "internet_lag2"
# [113] "cliente_edad_lag2"
# [114] "cliente_antiguedad_lag2"
# [115] "mrentabilidad_lag2"
# [116] "mrentabilidad_annual_lag2"
# [117] "mcomisiones_lag2"
# [118] "mactivos_margen_lag2"
# [119] "mpasivos_margen_lag2"
# [120] "cproductos_lag2"
# [121] "mcuenta_corriente_lag2"
# [122] "mcaja_ahorro_lag2"
# [123] "cdescubierto_preacordado_lag2"
# [124] "mcuentas_saldo_lag2"
# [125] "ctarjeta_visa_lag2"
# [126] "ctarjeta_visa_transacciones_lag2"
# [127] "mtarjeta_visa_consumo_lag2"
# [128] "ctarjeta_master_lag2"
# [129] "ctarjeta_master_transacciones_lag2"
# [130] "mtarjeta_master_consumo_lag2"
# [131] "cprestamos_personales_lag2"
# [132] "mprestamos_personales_lag2"
# [133] "cpayroll_trx_lag2"
# [134] "mpayroll_lag2"
# [135] "mttarjeta_visa_debitos_automaticos_lag2"
# [136] "ccomisiones_mantenimiento_lag2"
# [137] "mcomisiones_mantenimiento_lag2"
# [138] "ccomisiones_otras_lag2"
# [139] "mtransferencias_recibidas_lag2"
# [140] "ccallcenter_transacciones_lag2"
# [141] "thomebanking_lag2"
# [142] "chomebanking_transacciones_lag2"
# [143] "ctrx_quarter_lag2"
# [144] "Master_status_lag2"
# [145] "Master_mfinanciacion_limite_lag2"
# [146] "Master_Fvencimiento_lag2"
# [147] "Master_msaldototal_lag2"
# [148] "Master_mlimitecompra_lag2"
# [149] "Master_fultimo_cierre_lag2"
# [150] "Master_fechaalta_lag2"
# [151] "Master_mconsumototal_lag2"
# [152] "Master_cconsumos_lag2"
# [153] "Master_mpagominimo_lag2"
# [154] "Visa_status_lag2"
# [155] "Visa_mfinanciacion_limite_lag2"
# [156] "Visa_Fvencimiento_lag2"
# [157] "Visa_msaldototal_lag2"
# [158] "Visa_mlimitecompra_lag2"
# [159] "Visa_fultimo_cierre_lag2"
# [160] "Visa_fechaalta_lag2"
# [161] "Visa_mconsumototal_lag2"
# [162] "Visa_cconsumos_lag2"
# [163] "Visa_mpagominimo_lag2"
# [164] "kmes_lag2"
# [165] "mpayroll_sobre_edad_lag2"
# [166] "internet_lag3"
# [167] "cliente_edad_lag3"
# [168] "cliente_antiguedad_lag3"
# [169] "mrentabilidad_lag3"
# [170] "mrentabilidad_annual_lag3"
# [171] "mcomisiones_lag3"
# [172] "mactivos_margen_lag3"
# [173] "mpasivos_margen_lag3"
# [174] "cproductos_lag3"
# [175] "mcuenta_corriente_lag3"
# [176] "mcaja_ahorro_lag3"
# [177] "cdescubierto_preacordado_lag3"
# [178] "mcuentas_saldo_lag3"
# [179] "ctarjeta_visa_lag3"
# [180] "ctarjeta_visa_transacciones_lag3"
# [181] "mtarjeta_visa_consumo_lag3"
# [182] "ctarjeta_master_lag3"
# [183] "ctarjeta_master_transacciones_lag3"
# [184] "mtarjeta_master_consumo_lag3"
# [185] "cprestamos_personales_lag3"
# [186] "mprestamos_personales_lag3"
# [187] "cpayroll_trx_lag3"
# [188] "mpayroll_lag3"
# [189] "mttarjeta_visa_debitos_automaticos_lag3"
# [190] "ccomisiones_mantenimiento_lag3"
# [191] "mcomisiones_mantenimiento_lag3"
# [192] "ccomisiones_otras_lag3"
# [193] "mtransferencias_recibidas_lag3"
# [194] "ccallcenter_transacciones_lag3"
# [195] "thomebanking_lag3"
# [196] "chomebanking_transacciones_lag3"
# [197] "ctrx_quarter_lag3"
# [198] "Master_status_lag3"
# [199] "Master_mfinanciacion_limite_lag3"
# [200] "Master_Fvencimiento_lag3"
# [201] "Master_msaldototal_lag3"
# [202] "Master_mlimitecompra_lag3"
# [203] "Master_fultimo_cierre_lag3"
# [204] "Master_fechaalta_lag3"
# [205] "Master_mconsumototal_lag3"
# [206] "Master_cconsumos_lag3"
# [207] "Master_mpagominimo_lag3"
# [208] "Visa_status_lag3"
# [209] "Visa_mfinanciacion_limite_lag3"
# [210] "Visa_Fvencimiento_lag3"
# [211] "Visa_msaldototal_lag3"
# [212] "Visa_mlimitecompra_lag3"
# [213] "Visa_fultimo_cierre_lag3"
# [214] "Visa_fechaalta_lag3"
# [215] "Visa_mconsumototal_lag3"
# [216] "Visa_cconsumos_lag3"
# [217] "Visa_mpagominimo_lag3"
# [218] "kmes_lag3"
# [219] "mpayroll_sobre_edad_lag3"
# [220] "internet_lag6"
# [221] "cliente_edad_lag6"
# [222] "cliente_antiguedad_lag6"
# [223] "mrentabilidad_lag6"
# [224] "mrentabilidad_annual_lag6"
# [225] "mcomisiones_lag6"
# [226] "mactivos_margen_lag6"
# [227] "mpasivos_margen_lag6"
# [228] "cproductos_lag6"
# [229] "mcuenta_corriente_lag6"
# [230] "mcaja_ahorro_lag6"
# [231] "cdescubierto_preacordado_lag6"
# [232] "mcuentas_saldo_lag6"
# [233] "ctarjeta_visa_lag6"
# [234] "ctarjeta_visa_transacciones_lag6"
# [235] "mtarjeta_visa_consumo_lag6"
# [236] "ctarjeta_master_lag6"
# [237] "ctarjeta_master_transacciones_lag6"
# [238] "mtarjeta_master_consumo_lag6"
# [239] "cprestamos_personales_lag6"
# [240] "mprestamos_personales_lag6"
# [241] "cpayroll_trx_lag6"
# [242] "mpayroll_lag6"
# [243] "mttarjeta_visa_debitos_automaticos_lag6"
# [244] "ccomisiones_mantenimiento_lag6"
# [245] "mcomisiones_mantenimiento_lag6"
# [246] "ccomisiones_otras_lag6"
# [247] "mtransferencias_recibidas_lag6"
# [248] "ccallcenter_transacciones_lag6"
# [249] "thomebanking_lag6"
# [250] "chomebanking_transacciones_lag6"
# [251] "ctrx_quarter_lag6"
# [252] "Master_status_lag6"
# [253] "Master_mfinanciacion_limite_lag6"
# [254] "Master_Fvencimiento_lag6"
# [255] "Master_msaldototal_lag6"
# [256] "Master_mlimitecompra_lag6"
# [257] "Master_fultimo_cierre_lag6"
# [258] "Master_fechaalta_lag6"
# [259] "Master_mconsumototal_lag6"
# [260] "Master_cconsumos_lag6"
# [261] "Master_mpagominimo_lag6"
# [262] "Visa_status_lag6"
# [263] "Visa_mfinanciacion_limite_lag6"
# [264] "Visa_Fvencimiento_lag6"
# [265] "Visa_msaldototal_lag6"
# [266] "Visa_mlimitecompra_lag6"
# [267] "Visa_fultimo_cierre_lag6"
# [268] "Visa_fechaalta_lag6"
# [269] "Visa_mconsumototal_lag6"
# [270] "Visa_cconsumos_lag6"
# [271] "Visa_mpagominimo_lag6"
# [272] "kmes_lag6"
# [273] "mpayroll_sobre_edad_lag6"
# [274] "internet_lag12"
# [275] "cliente_edad_lag12"
# [276] "cliente_antiguedad_lag12"
# [277] "mrentabilidad_lag12"
# [278] "mrentabilidad_annual_lag12"
# [279] "mcomisiones_lag12"
# [280] "mactivos_margen_lag12"
# [281] "mpasivos_margen_lag12"
# [282] "cproductos_lag12"
# [283] "mcuenta_corriente_lag12"
# [284] "mcaja_ahorro_lag12"
# [285] "cdescubierto_preacordado_lag12"
# [286] "mcuentas_saldo_lag12"
# [287] "ctarjeta_visa_lag12"
# [288] "ctarjeta_visa_transacciones_lag12"
# [289] "mtarjeta_visa_consumo_lag12"
# [290] "ctarjeta_master_lag12"
# [291] "ctarjeta_master_transacciones_lag12"
# [292] "mtarjeta_master_consumo_lag12"
# [293] "cprestamos_personales_lag12"
# [294] "mprestamos_personales_lag12"
# [295] "cpayroll_trx_lag12"
# [296] "mpayroll_lag12"
# [297] "mttarjeta_visa_debitos_automaticos_lag12"
# [298] "ccomisiones_mantenimiento_lag12"
# [299] "mcomisiones_mantenimiento_lag12"
# [300] "ccomisiones_otras_lag12"
# [301] "mtransferencias_recibidas_lag12"
# [302] "ccallcenter_transacciones_lag12"
# [303] "thomebanking_lag12"
# [304] "chomebanking_transacciones_lag12"
# [305] "ctrx_quarter_lag12"
# [306] "Master_status_lag12"
# [307] "Master_mfinanciacion_limite_lag12"
# [308] "Master_Fvencimiento_lag12"
# [309] "Master_msaldototal_lag12"
# [310] "Master_mlimitecompra_lag12"
# [311] "Master_fultimo_cierre_lag12"
# [312] "Master_fechaalta_lag12"
# [313] "Master_mconsumototal_lag12"
# [314] "Master_cconsumos_lag12"
# [315] "Master_mpagominimo_lag12"
# [316] "Visa_status_lag12"
# [317] "Visa_mfinanciacion_limite_lag12"
# [318] "Visa_Fvencimiento_lag12"
# [319] "Visa_msaldototal_lag12"
# [320] "Visa_mlimitecompra_lag12"
# [321] "Visa_fultimo_cierre_lag12"
# [322] "Visa_fechaalta_lag12"
# [323] "Visa_mconsumototal_lag12"
# [324] "Visa_cconsumos_lag12"
# [325] "Visa_mpagominimo_lag12"
# [326] "kmes_lag12"
# [327] "mpayroll_sobre_edad_lag12"
# [328] "internet_delta1"
# [329] "internet_deltapct1"
# [330] "cliente_edad_delta1"
# [331] "cliente_edad_deltapct1"
# [332] "cliente_antiguedad_delta1"
# [333] "cliente_antiguedad_deltapct1"
# [334] "mrentabilidad_delta1"
# [335] "mrentabilidad_deltapct1"
# [336] "mrentabilidad_annual_delta1"
# [337] "mrentabilidad_annual_deltapct1"
# [338] "mcomisiones_delta1"
# [339] "mcomisiones_deltapct1"
# [340] "mactivos_margen_delta1"
# [341] "mactivos_margen_deltapct1"
# [342] "mpasivos_margen_delta1"
# [343] "mpasivos_margen_deltapct1"
# [344] "cproductos_delta1"
# [345] "cproductos_deltapct1"
# [346] "mcuenta_corriente_delta1"
# [347] "mcuenta_corriente_deltapct1"
# [348] "mcaja_ahorro_delta1"
# [349] "mcaja_ahorro_deltapct1"
# [350] "cdescubierto_preacordado_delta1"
# [351] "cdescubierto_preacordado_deltapct1"
# [352] "mcuentas_saldo_delta1"
# [353] "mcuentas_saldo_deltapct1"
# [354] "ctarjeta_visa_delta1"
# [355] "ctarjeta_visa_deltapct1"
# [356] "ctarjeta_visa_transacciones_delta1"
# [357] "ctarjeta_visa_transacciones_deltapct1"
# [358] "mtarjeta_visa_consumo_delta1"
# [359] "mtarjeta_visa_consumo_deltapct1"
# [360] "ctarjeta_master_delta1"
# [361] "ctarjeta_master_deltapct1"
# [362] "ctarjeta_master_transacciones_delta1"
# [363] "ctarjeta_master_transacciones_deltapct1"
# [364] "mtarjeta_master_consumo_delta1"
# [365] "mtarjeta_master_consumo_deltapct1"
# [366] "cprestamos_personales_delta1"
# [367] "cprestamos_personales_deltapct1"
# [368] "mprestamos_personales_delta1"
# [369] "mprestamos_personales_deltapct1"
# [370] "cpayroll_trx_delta1"
# [371] "cpayroll_trx_deltapct1"
# [372] "mpayroll_delta1"
# [373] "mpayroll_deltapct1"
# [374] "mttarjeta_visa_debitos_automaticos_delta1"
# [375] "mttarjeta_visa_debitos_automaticos_deltapct1"
# [376] "ccomisiones_mantenimiento_delta1"
# [377] "ccomisiones_mantenimiento_deltapct1"
# [378] "mcomisiones_mantenimiento_delta1"
# [379] "mcomisiones_mantenimiento_deltapct1"
# [380] "ccomisiones_otras_delta1"
# [381] "ccomisiones_otras_deltapct1"
# [382] "mtransferencias_recibidas_delta1"
# [383] "mtransferencias_recibidas_deltapct1"
# [384] "ccallcenter_transacciones_delta1"
# [385] "ccallcenter_transacciones_deltapct1"
# [386] "thomebanking_delta1"
# [387] "thomebanking_deltapct1"
# [388] "chomebanking_transacciones_delta1"
# [389] "chomebanking_transacciones_deltapct1"
# [390] "ctrx_quarter_delta1"
# [391] "ctrx_quarter_deltapct1"
# [392] "Master_status_delta1"
# [393] "Master_status_deltapct1"
# [394] "Master_mfinanciacion_limite_delta1"
# [395] "Master_mfinanciacion_limite_deltapct1"
# [396] "Master_Fvencimiento_delta1"
# [397] "Master_Fvencimiento_deltapct1"
# [398] "Master_msaldototal_delta1"
# [399] "Master_msaldototal_deltapct1"
# [400] "Master_mlimitecompra_delta1"
# [401] "Master_mlimitecompra_deltapct1"
# [402] "Master_fultimo_cierre_delta1"
# [403] "Master_fultimo_cierre_deltapct1"
# [404] "Master_fechaalta_delta1"
# [405] "Master_fechaalta_deltapct1"
# [406] "Master_mconsumototal_delta1"
# [407] "Master_mconsumototal_deltapct1"
# [408] "Master_cconsumos_delta1"
# [409] "Master_cconsumos_deltapct1"
# [410] "Master_mpagominimo_delta1"
# [411] "Master_mpagominimo_deltapct1"
# [412] "Visa_status_delta1"
# [413] "Visa_status_deltapct1"
# [414] "Visa_mfinanciacion_limite_delta1"
# [415] "Visa_mfinanciacion_limite_deltapct1"
# [416] "Visa_Fvencimiento_delta1"
# [417] "Visa_Fvencimiento_deltapct1"
# [418] "Visa_msaldototal_delta1"
# [419] "Visa_msaldototal_deltapct1"
# [420] "Visa_mlimitecompra_delta1"
# [421] "Visa_mlimitecompra_deltapct1"
# [422] "Visa_fultimo_cierre_delta1"
# [423] "Visa_fultimo_cierre_deltapct1"
# [424] "Visa_fechaalta_delta1"
# [425] "Visa_fechaalta_deltapct1"
# [426] "Visa_mconsumototal_delta1"
# [427] "Visa_mconsumototal_deltapct1"
# [428] "Visa_cconsumos_delta1"
# [429] "Visa_cconsumos_deltapct1"
# [430] "Visa_mpagominimo_delta1"
# [431] "Visa_mpagominimo_deltapct1"
# [432] "kmes_delta1"
# [433] "kmes_deltapct1"
# [434] "mpayroll_sobre_edad_delta1"
# [435] "mpayroll_sobre_edad_deltapct1"
# [436] "internet_delta2"
# [437] "internet_deltapct2"
# [438] "cliente_edad_delta2"
# [439] "cliente_edad_deltapct2"
# [440] "cliente_antiguedad_delta2"
# [441] "cliente_antiguedad_deltapct2"
# [442] "mrentabilidad_delta2"
# [443] "mrentabilidad_deltapct2"
# [444] "mrentabilidad_annual_delta2"
# [445] "mrentabilidad_annual_deltapct2"
# [446] "mcomisiones_delta2"
# [447] "mcomisiones_deltapct2"
# [448] "mactivos_margen_delta2"
# [449] "mactivos_margen_deltapct2"
# [450] "mpasivos_margen_delta2"
# [451] "mpasivos_margen_deltapct2"
# [452] "cproductos_delta2"
# [453] "cproductos_deltapct2"
# [454] "mcuenta_corriente_delta2"
# [455] "mcuenta_corriente_deltapct2"
# [456] "mcaja_ahorro_delta2"
# [457] "mcaja_ahorro_deltapct2"
# [458] "cdescubierto_preacordado_delta2"
# [459] "cdescubierto_preacordado_deltapct2"
# [460] "mcuentas_saldo_delta2"
# [461] "mcuentas_saldo_deltapct2"
# [462] "ctarjeta_visa_delta2"
# [463] "ctarjeta_visa_deltapct2"
# [464] "ctarjeta_visa_transacciones_delta2"
# [465] "ctarjeta_visa_transacciones_deltapct2"
# [466] "mtarjeta_visa_consumo_delta2"
# [467] "mtarjeta_visa_consumo_deltapct2"
# [468] "ctarjeta_master_delta2"
# [469] "ctarjeta_master_deltapct2"
# [470] "ctarjeta_master_transacciones_delta2"
# [471] "ctarjeta_master_transacciones_deltapct2"
# [472] "mtarjeta_master_consumo_delta2"
# [473] "mtarjeta_master_consumo_deltapct2"
# [474] "cprestamos_personales_delta2"
# [475] "cprestamos_personales_deltapct2"
# [476] "mprestamos_personales_delta2"
# [477] "mprestamos_personales_deltapct2"
# [478] "cpayroll_trx_delta2"
# [479] "cpayroll_trx_deltapct2"
# [480] "mpayroll_delta2"
# [481] "mpayroll_deltapct2"
# [482] "mttarjeta_visa_debitos_automaticos_delta2"
# [483] "mttarjeta_visa_debitos_automaticos_deltapct2"
# [484] "ccomisiones_mantenimiento_delta2"
# [485] "ccomisiones_mantenimiento_deltapct2"
# [486] "mcomisiones_mantenimiento_delta2"
# [487] "mcomisiones_mantenimiento_deltapct2"
# [488] "ccomisiones_otras_delta2"
# [489] "ccomisiones_otras_deltapct2"
# [490] "mtransferencias_recibidas_delta2"
# [491] "mtransferencias_recibidas_deltapct2"
# [492] "ccallcenter_transacciones_delta2"
# [493] "ccallcenter_transacciones_deltapct2"
# [494] "thomebanking_delta2"
# [495] "thomebanking_deltapct2"
# [496] "chomebanking_transacciones_delta2"
# [497] "chomebanking_transacciones_deltapct2"
# [498] "ctrx_quarter_delta2"
# [499] "ctrx_quarter_deltapct2"
# [500] "Master_status_delta2"
# [501] "Master_status_deltapct2"
# [502] "Master_mfinanciacion_limite_delta2"
# [503] "Master_mfinanciacion_limite_deltapct2"
# [504] "Master_Fvencimiento_delta2"
# [505] "Master_Fvencimiento_deltapct2"
# [506] "Master_msaldototal_delta2"
# [507] "Master_msaldototal_deltapct2"
# [508] "Master_mlimitecompra_delta2"
# [509] "Master_mlimitecompra_deltapct2"
# [510] "Master_fultimo_cierre_delta2"
# [511] "Master_fultimo_cierre_deltapct2"
# [512] "Master_fechaalta_delta2"
# [513] "Master_fechaalta_deltapct2"
# [514] "Master_mconsumototal_delta2"
# [515] "Master_mconsumototal_deltapct2"
# [516] "Master_cconsumos_delta2"
# [517] "Master_cconsumos_deltapct2"
# [518] "Master_mpagominimo_delta2"
# [519] "Master_mpagominimo_deltapct2"
# [520] "Visa_status_delta2"
# [521] "Visa_status_deltapct2"
# [522] "Visa_mfinanciacion_limite_delta2"
# [523] "Visa_mfinanciacion_limite_deltapct2"
# [524] "Visa_Fvencimiento_delta2"
# [525] "Visa_Fvencimiento_deltapct2"
# [526] "Visa_msaldototal_delta2"
# [527] "Visa_msaldototal_deltapct2"
# [528] "Visa_mlimitecompra_delta2"
# [529] "Visa_mlimitecompra_deltapct2"
# [530] "Visa_fultimo_cierre_delta2"
# [531] "Visa_fultimo_cierre_deltapct2"
# [532] "Visa_fechaalta_delta2"
# [533] "Visa_fechaalta_deltapct2"
# [534] "Visa_mconsumototal_delta2"
# [535] "Visa_mconsumototal_deltapct2"
# [536] "Visa_cconsumos_delta2"
# [537] "Visa_cconsumos_deltapct2"
# [538] "Visa_mpagominimo_delta2"
# [539] "Visa_mpagominimo_deltapct2"
# [540] "kmes_delta2"
# [541] "kmes_deltapct2"
# [542] "mpayroll_sobre_edad_delta2"
# [543] "mpayroll_sobre_edad_deltapct2"
# [544] "internet_delta3"
# [545] "internet_deltapct3"
# [546] "cliente_edad_delta3"
# [547] "cliente_edad_deltapct3"
# [548] "cliente_antiguedad_delta3"
# [549] "cliente_antiguedad_deltapct3"
# [550] "mrentabilidad_delta3"
# [551] "mrentabilidad_deltapct3"
# [552] "mrentabilidad_annual_delta3"
# [553] "mrentabilidad_annual_deltapct3"
# [554] "mcomisiones_delta3"
# [555] "mcomisiones_deltapct3"
# [556] "mactivos_margen_delta3"
# [557] "mactivos_margen_deltapct3"
# [558] "mpasivos_margen_delta3"
# [559] "mpasivos_margen_deltapct3"
# [560] "cproductos_delta3"
# [561] "cproductos_deltapct3"
# [562] "mcuenta_corriente_delta3"
# [563] "mcuenta_corriente_deltapct3"
# [564] "mcaja_ahorro_delta3"
# [565] "mcaja_ahorro_deltapct3"
# [566] "cdescubierto_preacordado_delta3"
# [567] "cdescubierto_preacordado_deltapct3"
# [568] "mcuentas_saldo_delta3"
# [569] "mcuentas_saldo_deltapct3"
# [570] "ctarjeta_visa_delta3"
# [571] "ctarjeta_visa_deltapct3"
# [572] "ctarjeta_visa_transacciones_delta3"
# [573] "ctarjeta_visa_transacciones_deltapct3"
# [574] "mtarjeta_visa_consumo_delta3"
# [575] "mtarjeta_visa_consumo_deltapct3"
# [576] "ctarjeta_master_delta3"
# [577] "ctarjeta_master_deltapct3"
# [578] "ctarjeta_master_transacciones_delta3"
# [579] "ctarjeta_master_transacciones_deltapct3"
# [580] "mtarjeta_master_consumo_delta3"
# [581] "mtarjeta_master_consumo_deltapct3"
# [582] "cprestamos_personales_delta3"
# [583] "cprestamos_personales_deltapct3"
# [584] "mprestamos_personales_delta3"
# [585] "mprestamos_personales_deltapct3"
# [586] "cpayroll_trx_delta3"
# [587] "cpayroll_trx_deltapct3"
# [588] "mpayroll_delta3"
# [589] "mpayroll_deltapct3"
# [590] "mttarjeta_visa_debitos_automaticos_delta3"
# [591] "mttarjeta_visa_debitos_automaticos_deltapct3"
# [592] "ccomisiones_mantenimiento_delta3"
# [593] "ccomisiones_mantenimiento_deltapct3"
# [594] "mcomisiones_mantenimiento_delta3"
# [595] "mcomisiones_mantenimiento_deltapct3"
# [596] "ccomisiones_otras_delta3"
# [597] "ccomisiones_otras_deltapct3"
# [598] "mtransferencias_recibidas_delta3"
# [599] "mtransferencias_recibidas_deltapct3"
# [600] "ccallcenter_transacciones_delta3"
# [601] "ccallcenter_transacciones_deltapct3"
# [602] "thomebanking_delta3"
# [603] "thomebanking_deltapct3"
# [604] "chomebanking_transacciones_delta3"
# [605] "chomebanking_transacciones_deltapct3"
# [606] "ctrx_quarter_delta3"
# [607] "ctrx_quarter_deltapct3"
# [608] "Master_status_delta3"
# [609] "Master_status_deltapct3"
# [610] "Master_mfinanciacion_limite_delta3"
# [611] "Master_mfinanciacion_limite_deltapct3"
# [612] "Master_Fvencimiento_delta3"
# [613] "Master_Fvencimiento_deltapct3"
# [614] "Master_msaldototal_delta3"
# [615] "Master_msaldototal_deltapct3"
# [616] "Master_mlimitecompra_delta3"
# [617] "Master_mlimitecompra_deltapct3"
# [618] "Master_fultimo_cierre_delta3"
# [619] "Master_fultimo_cierre_deltapct3"
# [620] "Master_fechaalta_delta3"
# [621] "Master_fechaalta_deltapct3"
# [622] "Master_mconsumototal_delta3"
# [623] "Master_mconsumototal_deltapct3"
# [624] "Master_cconsumos_delta3"
# [625] "Master_cconsumos_deltapct3"
# [626] "Master_mpagominimo_delta3"
# [627] "Master_mpagominimo_deltapct3"
# [628] "Visa_status_delta3"
# [629] "Visa_status_deltapct3"
# [630] "Visa_mfinanciacion_limite_delta3"
# [631] "Visa_mfinanciacion_limite_deltapct3"
# [632] "Visa_Fvencimiento_delta3"
# [633] "Visa_Fvencimiento_deltapct3"
# [634] "Visa_msaldototal_delta3"
# [635] "Visa_msaldototal_deltapct3"
# [636] "Visa_mlimitecompra_delta3"
# [637] "Visa_mlimitecompra_deltapct3"
# [638] "Visa_fultimo_cierre_delta3"
# [639] "Visa_fultimo_cierre_deltapct3"
# [640] "Visa_fechaalta_delta3"
# [641] "Visa_fechaalta_deltapct3"
# [642] "Visa_mconsumototal_delta3"
# [643] "Visa_mconsumototal_deltapct3"
# [644] "Visa_cconsumos_delta3"
# [645] "Visa_cconsumos_deltapct3"
# [646] "Visa_mpagominimo_delta3"
# [647] "Visa_mpagominimo_deltapct3"
# [648] "kmes_delta3"
# [649] "kmes_deltapct3"
# [650] "mpayroll_sobre_edad_delta3"
# [651] "mpayroll_sobre_edad_deltapct3"
# [652] "internet_delta6"
# [653] "internet_deltapct6"
# [654] "cliente_edad_delta6"
# [655] "cliente_edad_deltapct6"
# [656] "cliente_antiguedad_delta6"
# [657] "cliente_antiguedad_deltapct6"
# [658] "mrentabilidad_delta6"
# [659] "mrentabilidad_deltapct6"
# [660] "mrentabilidad_annual_delta6"
# [661] "mrentabilidad_annual_deltapct6"
# [662] "mcomisiones_delta6"
# [663] "mcomisiones_deltapct6"
# [664] "mactivos_margen_delta6"
# [665] "mactivos_margen_deltapct6"
# [666] "mpasivos_margen_delta6"
# [667] "mpasivos_margen_deltapct6"
# [668] "cproductos_delta6"
# [669] "cproductos_deltapct6"
# [670] "mcuenta_corriente_delta6"
# [671] "mcuenta_corriente_deltapct6"
# [672] "mcaja_ahorro_delta6"
# [673] "mcaja_ahorro_deltapct6"
# [674] "cdescubierto_preacordado_delta6"
# [675] "cdescubierto_preacordado_deltapct6"
# [676] "mcuentas_saldo_delta6"
# [677] "mcuentas_saldo_deltapct6"
# [678] "ctarjeta_visa_delta6"
# [679] "ctarjeta_visa_deltapct6"
# [680] "ctarjeta_visa_transacciones_delta6"
# [681] "ctarjeta_visa_transacciones_deltapct6"
# [682] "mtarjeta_visa_consumo_delta6"
# [683] "mtarjeta_visa_consumo_deltapct6"
# [684] "ctarjeta_master_delta6"
# [685] "ctarjeta_master_deltapct6"
# [686] "ctarjeta_master_transacciones_delta6"
# [687] "ctarjeta_master_transacciones_deltapct6"
# [688] "mtarjeta_master_consumo_delta6"
# [689] "mtarjeta_master_consumo_deltapct6"
# [690] "cprestamos_personales_delta6"
# [691] "cprestamos_personales_deltapct6"
# [692] "mprestamos_personales_delta6"
# [693] "mprestamos_personales_deltapct6"
# [694] "cpayroll_trx_delta6"
# [695] "cpayroll_trx_deltapct6"
# [696] "mpayroll_delta6"
# [697] "mpayroll_deltapct6"
# [698] "mttarjeta_visa_debitos_automaticos_delta6"
# [699] "mttarjeta_visa_debitos_automaticos_deltapct6"
# [700] "ccomisiones_mantenimiento_delta6"
# [701] "ccomisiones_mantenimiento_deltapct6"
# [702] "mcomisiones_mantenimiento_delta6"
# [703] "mcomisiones_mantenimiento_deltapct6"
# [704] "ccomisiones_otras_delta6"
# [705] "ccomisiones_otras_deltapct6"
# [706] "mtransferencias_recibidas_delta6"
# [707] "mtransferencias_recibidas_deltapct6"
# [708] "ccallcenter_transacciones_delta6"
# [709] "ccallcenter_transacciones_deltapct6"
# [710] "thomebanking_delta6"
# [711] "thomebanking_deltapct6"
# [712] "chomebanking_transacciones_delta6"
# [713] "chomebanking_transacciones_deltapct6"
# [714] "ctrx_quarter_delta6"
# [715] "ctrx_quarter_deltapct6"
# [716] "Master_status_delta6"
# [717] "Master_status_deltapct6"
# [718] "Master_mfinanciacion_limite_delta6"
# [719] "Master_mfinanciacion_limite_deltapct6"
# [720] "Master_Fvencimiento_delta6"
# [721] "Master_Fvencimiento_deltapct6"
# [722] "Master_msaldototal_delta6"
# [723] "Master_msaldototal_deltapct6"
# [724] "Master_mlimitecompra_delta6"
# [725] "Master_mlimitecompra_deltapct6"
# [726] "Master_fultimo_cierre_delta6"
# [727] "Master_fultimo_cierre_deltapct6"
# [728] "Master_fechaalta_delta6"
# [729] "Master_fechaalta_deltapct6"
# [730] "Master_mconsumototal_delta6"
# [731] "Master_mconsumototal_deltapct6"
# [732] "Master_cconsumos_delta6"
# [733] "Master_cconsumos_deltapct6"
# [734] "Master_mpagominimo_delta6"
# [735] "Master_mpagominimo_deltapct6"
# [736] "Visa_status_delta6"
# [737] "Visa_status_deltapct6"
# [738] "Visa_mfinanciacion_limite_delta6"
# [739] "Visa_mfinanciacion_limite_deltapct6"
# [740] "Visa_Fvencimiento_delta6"
# [741] "Visa_Fvencimiento_deltapct6"
# [742] "Visa_msaldototal_delta6"
# [743] "Visa_msaldototal_deltapct6"
# [744] "Visa_mlimitecompra_delta6"
# [745] "Visa_mlimitecompra_deltapct6"
# [746] "Visa_fultimo_cierre_delta6"
# [747] "Visa_fultimo_cierre_deltapct6"
# [748] "Visa_fechaalta_delta6"
# [749] "Visa_fechaalta_deltapct6"
# [750] "Visa_mconsumototal_delta6"
# [751] "Visa_mconsumototal_deltapct6"
# [752] "Visa_cconsumos_delta6"
# [753] "Visa_cconsumos_deltapct6"
# [754] "Visa_mpagominimo_delta6"
# [755] "Visa_mpagominimo_deltapct6"
# [756] "kmes_delta6"
# [757] "kmes_deltapct6"
# [758] "mpayroll_sobre_edad_delta6"
# [759] "mpayroll_sobre_edad_deltapct6"
# [760] "internet_delta12"
# [761] "internet_deltapct12"
# [762] "cliente_edad_delta12"
# [763] "cliente_edad_deltapct12"
# [764] "cliente_antiguedad_delta12"
# [765] "cliente_antiguedad_deltapct12"
# [766] "mrentabilidad_delta12"
# [767] "mrentabilidad_deltapct12"
# [768] "mrentabilidad_annual_delta12"
# [769] "mrentabilidad_annual_deltapct12"
# [770] "mcomisiones_delta12"
# [771] "mcomisiones_deltapct12"
# [772] "mactivos_margen_delta12"
# [773] "mactivos_margen_deltapct12"
# [774] "mpasivos_margen_delta12"
# [775] "mpasivos_margen_deltapct12"
# [776] "cproductos_delta12"
# [777] "cproductos_deltapct12"
# [778] "mcuenta_corriente_delta12"
# [779] "mcuenta_corriente_deltapct12"
# [780] "mcaja_ahorro_delta12"
# [781] "mcaja_ahorro_deltapct12"
# [782] "cdescubierto_preacordado_delta12"
# [783] "cdescubierto_preacordado_deltapct12"
# [784] "mcuentas_saldo_delta12"
# [785] "mcuentas_saldo_deltapct12"
# [786] "ctarjeta_visa_delta12"
# [787] "ctarjeta_visa_deltapct12"
# [788] "ctarjeta_visa_transacciones_delta12"
# [789] "ctarjeta_visa_transacciones_deltapct12"
# [790] "mtarjeta_visa_consumo_delta12"
# [791] "mtarjeta_visa_consumo_deltapct12"
# [792] "ctarjeta_master_delta12"
# [793] "ctarjeta_master_deltapct12"
# [794] "ctarjeta_master_transacciones_delta12"
# [795] "ctarjeta_master_transacciones_deltapct12"
# [796] "mtarjeta_master_consumo_delta12"
# [797] "mtarjeta_master_consumo_deltapct12"
# [798] "cprestamos_personales_delta12"
# [799] "cprestamos_personales_deltapct12"
# [800] "mprestamos_personales_delta12"
# [801] "mprestamos_personales_deltapct12"
# [802] "cpayroll_trx_delta12"
# [803] "cpayroll_trx_deltapct12"
# [804] "mpayroll_delta12"
# [805] "mpayroll_deltapct12"
# [806] "mttarjeta_visa_debitos_automaticos_delta12"
# [807] "mttarjeta_visa_debitos_automaticos_deltapct12"
# [808] "ccomisiones_mantenimiento_delta12"
# [809] "ccomisiones_mantenimiento_deltapct12"
# [810] "mcomisiones_mantenimiento_delta12"
# [811] "mcomisiones_mantenimiento_deltapct12"
# [812] "ccomisiones_otras_delta12"
# [813] "ccomisiones_otras_deltapct12"
# [814] "mtransferencias_recibidas_delta12"
# [815] "mtransferencias_recibidas_deltapct12"
# [816] "ccallcenter_transacciones_delta12"
# [817] "ccallcenter_transacciones_deltapct12"
# [818] "thomebanking_delta12"
# [819] "thomebanking_deltapct12"
# [820] "chomebanking_transacciones_delta12"
# [821] "chomebanking_transacciones_deltapct12"
# [822] "ctrx_quarter_delta12"
# [823] "ctrx_quarter_deltapct12"
# [824] "Master_status_delta12"
# [825] "Master_status_deltapct12"
# [826] "Master_mfinanciacion_limite_delta12"
# [827] "Master_mfinanciacion_limite_deltapct12"
# [828] "Master_Fvencimiento_delta12"
# [829] "Master_Fvencimiento_deltapct12"
# [830] "Master_msaldototal_delta12"
# [831] "Master_msaldototal_deltapct12"
# [832] "Master_mlimitecompra_delta12"
# [833] "Master_mlimitecompra_deltapct12"
# [834] "Master_fultimo_cierre_delta12"
# [835] "Master_fultimo_cierre_deltapct12"
# [836] "Master_fechaalta_delta12"
# [837] "Master_fechaalta_deltapct12"
# [838] "Master_mconsumototal_delta12"
# [839] "Master_mconsumototal_deltapct12"
# [840] "Master_cconsumos_delta12"
# [841] "Master_cconsumos_deltapct12"
# [842] "Master_mpagominimo_delta12"
# [843] "Master_mpagominimo_deltapct12"
# [844] "Visa_status_delta12"
# [845] "Visa_status_deltapct12"
# [846] "Visa_mfinanciacion_limite_delta12"
# [847] "Visa_mfinanciacion_limite_deltapct12"
# [848] "Visa_Fvencimiento_delta12"
# [849] "Visa_Fvencimiento_deltapct12"
# [850] "Visa_msaldototal_delta12"
# [851] "Visa_msaldototal_deltapct12"
# [852] "Visa_mlimitecompra_delta12"
# [853] "Visa_mlimitecompra_deltapct12"
# [854] "Visa_fultimo_cierre_delta12"
# [855] "Visa_fultimo_cierre_deltapct12"
# [856] "Visa_fechaalta_delta12"
# [857] "Visa_fechaalta_deltapct12"
# [858] "Visa_mconsumototal_delta12"
# [859] "Visa_mconsumototal_deltapct12"
# [860] "Visa_cconsumos_delta12"
# [861] "Visa_cconsumos_deltapct12"
# [862] "Visa_mpagominimo_delta12"
# [863] "Visa_mpagominimo_deltapct12"
# [864] "kmes_delta12"
# [865] "kmes_deltapct12"
# [866] "mpayroll_sobre_edad_delta12"
# [867] "mpayroll_sobre_edad_deltapct12"

# %% [markdown]
# #### 9.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest

# %%
if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: lightgbm

# %%
AgregaVarRandomForest <- function() {

  cat( "inicio AgregaVarRandomForest()\n")
  gc(verbose= FALSE)
  dataset[, clase01 := 0L ]
  dataset[ clase_ternaria %in% PARAM$FE_rf$train$clase01_valor1,
      clase01 := 1L ]

  campos_buenos <- setdiff(
    colnames(dataset),
    c( "clase_ternaria", "clase01")
  )

  dataset[, entrenamiento :=
    as.integer( foto_mes %in% PARAM$FE_rf$train$training )]

  dtrain <- lgb.Dataset(
    data = data.matrix(dataset[entrenamiento == TRUE, campos_buenos, with = FALSE]),
    label = dataset[entrenamiento == TRUE, clase01],
    free_raw_data = FALSE
  )

  modelo <- lgb.train(
     data = dtrain,
     param = PARAM$FE_rf$lgb_param,
     verbose = -100
  )

  cat( "Fin construccion RandomForest\n" )
  # grabo el modelo, achivo .model
  lgb.save(modelo, file="modelo.model" )

  qarbolitos <- copy(PARAM$FE_rf$lgb_param$num_iterations)

  periodos <- dataset[ , unique( foto_mes ) ]

  for( periodo in  periodos )
  {
    cat( "periodo = ", periodo, "\n" )
    datamatrix <- data.matrix(dataset[ foto_mes== periodo, campos_buenos, with = FALSE])

    cat( "Inicio prediccion\n" )
    prediccion <- predict(
        modelo,
        datamatrix,
        type = "leaf"
    )
    cat( "Fin prediccion\n" )

    for( arbolito in 1:qarbolitos )
    {
       cat( arbolito, " " )
       hojas_arbol <- unique(prediccion[ , arbolito])

       for (pos in 1:length(hojas_arbol)) {
         # el numero de nodo de la hoja, estan salteados
         nodo_id <- hojas_arbol[pos]
         dataset[ foto_mes== periodo, paste0(
            "rf_", sprintf("%03d", arbolito),
             "_", sprintf("%03d", nodo_id)
          ) :=  as.integer( nodo_id == prediccion[ , arbolito]) ]

       }

       rm( hojas_arbol )
    }
    cat( "\n" )

    rm( prediccion )
    rm( datamatrix )
    gc(verbose= FALSE)
  }

  gc(verbose= FALSE)

  # borro clase01 , no debe ensuciar el dataset
  dataset[ , clase01 := NULL ]

}

# %%
# Parametros de Feature Engineering  a partir de hojas de Random Forest

# Estos CUATRO parametros son los que se deben modificar
PARAM$FE_rf$arbolitos= 20
PARAM$FE_rf$hojas_por_arbol= 16
PARAM$FE_rf$datos_por_hoja= 100
PARAM$FE_rf$mtry_ratio= 0.2

# Estos son quasi fijos
PARAM$FE_rf$train$clase01_valor1 <- c( "BAJA+2", "BAJA+1")
PARAM$FE_rf$train$training <- c( 202101, 202102, 202103)

# Estos TAMBIEN son quasi fijos
PARAM$FE_rf$lgb_param <-list(
    # parametros que se pueden cambiar
    num_iterations = PARAM$FE_rf$arbolitos,
    num_leaves  = PARAM$FE_rf$hojas_por_arbol,
    min_data_in_leaf = PARAM$FE_rf$datos_por_hoja,
    feature_fraction_bynode  = PARAM$FE_rf$mtry_ratio,

    # para que LightGBM emule Random Forest
    boosting = "rf",
    bagging_fraction = ( 1.0 - 1.0/exp(1.0) ),
    bagging_freq = 1.0,
    feature_fraction = 1.0,

    # genericos de LightGBM
    max_bin = 31L,
    objective = "binary",
    first_metric_only = TRUE,
    boost_from_average = TRUE,
    feature_pre_filter = FALSE,
    force_row_wise = TRUE,
    verbosity = -100,
    max_depth = -1L,
    min_gain_to_split = 0.0,
    min_sum_hessian_in_leaf = 0.001,
    lambda_l1 = 0.0,
    lambda_l2 = 0.0,

    pos_bagging_fraction = 1.0,
    neg_bagging_fraction = 1.0,
    is_unbalance = FALSE,
    scale_pos_weight = 1.0,

    drop_rate = 0.1,
    max_drop = 50,
    skip_drop = 0.5,

    extra_trees = FALSE
  )

# %%
# Feature Engineering agregando variables de Random Forest
AgregaVarRandomForest()

# %%
ncol(dataset)
colnames(dataset)

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# Verificacion de los campos recien creados

# %% [markdown]
# #### 9.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
VPOS_CORTE <- c()

fganancia_lgbm_meseta <- function(probs, datos) {
  vlabels <- get_field(datos, "label")
  vpesos <- get_field(datos, "weight")

  tbl <- as.data.table(list(
    "prob" = probs,
    "gan" = ifelse(vlabels == 1 & vpesos > 1, PARAM$CN$train$gan1, PARAM$CN$train$gan0)
  ))

  setorder(tbl, -prob)
  tbl[, posicion := .I]
  tbl[, gan_acum := cumsum(gan)]
  setorder(tbl, -gan_acum) # voy por la meseta

  gan <- mean(tbl[1:500, gan_acum]) # meseta de tamaño 500

  pos_meseta <- tbl[1:500, median(posicion)]
  VPOS_CORTE <<- c(VPOS_CORTE, pos_meseta)

  return(list(
    "name" = "ganancia",
    "value" = gan,
    "higher_better" = TRUE
  ))
}

# %%
# Elimina del dataset las variables que estan por debajo
#  de la capa geologica de canaritos
# se llama varias veces, luego de agregar muchas variables nuevas,
#  para ir reduciendo la cantidad de variables
# y así hacer lugar a nuevas variables importantes

GVEZ <- 1

campitos <- c( "numero_de_cliente", "foto_mes", "clase_ternaria" )

CanaritosAsesinos <- function(
  canaritos_ratio,
  canaritos_desvios,
  canaritos_semilla) {

  cat( "inicio CanaritosAsesinos()\n")
  gc(verbose= FALSE)
  dataset[, clase01 := 0L ]
  dataset[ clase_ternaria %in% PARAM$CN$train$clase01_valor1,
      clase01 := 1L ]

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  for (i in 1:(ncol(dataset) * canaritos_ratio)) {
    dataset[, paste0("canarito", i) := runif(nrow(dataset))]
  }

  campos_buenos <- setdiff(
    colnames(dataset),
    c( campitos, "clase01")
  )

  azar <- runif(nrow(dataset))

  dataset[, entrenamiento :=
    as.integer( foto_mes %in% PARAM$CN$train$training &
      (clase01 == 1 | azar < PARAM$CN$train$undersampling))]

  dtrain <- lgb.Dataset(
    data = data.matrix(dataset[entrenamiento == TRUE, campos_buenos, with = FALSE]),
    label = dataset[entrenamiento == TRUE, clase01],
    weight = dataset[
      entrenamiento == TRUE,
      ifelse(clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )

  dvalid <- lgb.Dataset(
    data = data.matrix(dataset[foto_mes %in% PARAM$CN$train$validation, campos_buenos, with = FALSE]),
    label = dataset[foto_mes %in% PARAM$CN$train$validation, clase01],
    weight = dataset[
      foto_mes %in% PARAM$CN$train$validation,
      ifelse( clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )


  param <- list(
    objective = "binary",
    metric = "custom",
    first_metric_only = TRUE,
    boost_from_average = TRUE,
    feature_pre_filter = FALSE,
    verbosity = -100,
    seed = canaritos_semilla,
    max_depth = -1, # -1 significa no limitar,  por ahora lo dejo fijo
    min_gain_to_split = 0.0, # por ahora, lo dejo fijo
    lambda_l1 = 0.0, # por ahora, lo dejo fijo
    lambda_l2 = 0.0, # por ahora, lo dejo fijo
    max_bin = 31, # por ahora, lo dejo fijo
    num_iterations = 9999, # un numero grande, lo limita early_stopping_rounds
    force_row_wise = TRUE, # para que los alumnos no se atemoricen con  warning
    learning_rate = 0.065,
    feature_fraction = 1.0, # lo seteo en 1
    min_data_in_leaf = 260,
    num_leaves = 60,
    early_stopping_rounds = 200,
    num_threads = 1
  )

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  modelo <- lgb.train(
    data = dtrain,
    valids = list(valid = dvalid),
    eval = fganancia_lgbm_meseta,
    param = param,
    verbose = -100
  )

  tb_importancia <- lgb.importance(model = modelo)
  tb_importancia[, pos := .I]

  fwrite(tb_importancia,
    file = paste0("impo_", GVEZ, ".txt"),
    sep = "\t"
  )

  GVEZ <<- GVEZ + 1

  umbral <- tb_importancia[
    Feature %like% "canarito",
    median(pos) + canaritos_desvios * sd(pos)
  ] # Atencion corto en la mediana mas desvios!!

  col_utiles <- tb_importancia[
    pos < umbral & !(Feature %like% "canarito"),
    Feature
  ]

  col_utiles <- unique(c(
    col_utiles,
    c(campitos, "mes")
  ))

  col_inutiles <- setdiff(colnames(dataset), col_utiles)

  dataset[, (col_inutiles) := NULL]

  cat( "fin CanaritosAsesinos()\n")

  return( tb_importancia )
}

# %%
# Estos DOS parametros son los que se deben modificar
PARAM$CN$ratio <- 0.2
PARAM$CN$desvios <- 2


# Parametros quasi fijos
# Parametros de un LightGBM que se genera para estimar la column importance
PARAM$CN$train$clase01_valor1 <- c( "BAJA+2", "BAJA+1")
PARAM$CN$train$positivos <- c( "BAJA+2")
PARAM$CN$train$training <- c( 202101, 202102, 202103)
PARAM$CN$train$validation <- c( 202105 )
PARAM$CN$train$undersampling <- 0.1
PARAM$CN$train$gan1 <- 117000
PARAM$CN$train$gan0 <-  -3000

# %%
# la llamada a Canaritos Asesinos
tb_importancia <- CanaritosAsesinos(
  canaritos_ratio = PARAM$CN$ratio,
  canaritos_desvios = PARAM$CN$desvios,
  canaritos_semilla = PARAM$semilla_primigenia
)

# %%
# grabo la importancia, ver el archivo directamente en la carpeta

fwrite( tb_importancia,
  file="canaritos.txt",
  sep="\t"
)

# %%
# verifico
ncol(dataset)
colnames(dataset)

# %% [markdown]
# ### 9.3.2 Modelado

# %% [markdown]
# #### 9.3.2.1 Training Strategy

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 201901, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 201901, 202105 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105
)


PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 33053

# %% [markdown]
# ####  9.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# un Analista Jr  debe poder animarse a hacer 100 iteraciones
PARAM$hipeparametertuning$num_interations <- 20

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,

  num_iterations= 9999,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 400
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower= 2L, upper= 256L),
  makeIntegerParam("min_data_in_leaf", lower= 2L, upper= 8192L),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 0.9),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.5)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Warning message in mboContinue("HT.RDATA"):
# “Tuning ended with term.iter. No need to continue. Simply returning stored result.”

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf feature_fraction learning_rate num_iterations
#         <int>            <int>            <num>         <num>          <int>
# 1:        256             1793        0.1005058    0.01010846            601

# %% [markdown]
# ### 9.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106,
  202107
)


dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 910211

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labol-2025-virtual-analista-jr"
PARAM$kaggle$cortes <- seq(1800, 2400, by = 100)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
